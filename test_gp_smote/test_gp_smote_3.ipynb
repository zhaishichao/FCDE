# %% [markdown]
# ## 测试GP-SMOTE

# %%
from data_preprocess import data_loader, data_preprocess
from visualize import tsne_visualization_binary
from config import EvolutionaryParameterConfig
from gp_smote_test import DSSMOTE
import numpy as np
import warnings

warnings.filterwarnings("ignore")  # 忽略警告

file_path = '../datasets/dat/'
save_path = './0105_3/'
datasetnames = ['iris0', 'ecoli1', 'glass0', 'glass1', 'haberman', 'pima', 'segment0', 'vowel0', 'wisconsin', 'yeast1',
                'shuttle-c0-vs-c4', 'australian', 'heart', 'phoneme', 'ring', 'spambase', 'wdbc']
if __name__ == '__main__':
    print('########\t 开始执行！\t########')
    for datasetname in datasetnames:
        X, y = data_loader(file_path + datasetname + '.dat')
        X_train, X_test, y_train, y_test = data_preprocess(X, y, standard=True, random_state=42)
        # 使用t-SNE进行降维
        X_tsne = tsne_visualization_binary(X_train, y_train, save_path + datasetname, datasetname)  # 传入的是标准化后的特征数据

        # GPSMOTE
        evol_parameter = EvolutionaryParameterConfig(30, 0.8, 0.2, 100, False)
        dss = DSSMOTE(X=X_train, y=y_train, evol_parameter=evol_parameter)
        X_syn, y_syn = dss.fit_resample_synthesis_only()
        # 可视化, 将DSSMOTE生成的数据与原始数据进行拼接
        y_syn = [2 for _ in range(len(y_syn))]
        X_train_resampled = np.vstack((X_train, X_syn))
        y_train_resampled = np.hstack((y_train, y_syn))
        # 4. 使用t-SNE进行降维
        X_tsne_resampled_p_a = tsne_visualization_binary(X_train_resampled, y_train_resampled, save_path + datasetname,
                                                         datasetname + '_dss')
        dss.curve_fitting(save_path + datasetname + '/', 'convergence_curve', datasetname)
        with open(save_path +datasetname + '/'+datasetname +'.txt', 'w') as file:
            file.write(f'实例数量：{X.shape[0]}\n')
            file.write(f'特征数量：{X.shape[1]}\n')
    print('########\t 结束执行！\t########')
# Out:
# ########	 开始执行！	########
# t-SNE可视化图片已保存至: ./0105_3/iris0\iris0.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 5
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./0105_3/iris0\iris0_dss.png
# t-SNE可视化图片已保存至: ./0105_3/ecoli1\ecoli1.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 7
# 第 3 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 4 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 5
# 第 6 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 7 轮合成
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 5
# 第 8 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 9 轮合成
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 5
# 第 10 轮合成
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 5
# 第 11 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 12 轮合成
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 5
# 第 13 轮合成
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 5
# 第 14 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 15 轮合成
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 5
# 第 16 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 17 轮合成
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 5
# 第 18 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 19 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 20 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 21 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 22 轮合成
# 可行解数量： 30 前沿中个体数： 21 合成实例数： 21
# t-SNE可视化图片已保存至: ./0105_3/ecoli1\ecoli1_dss.png
# t-SNE可视化图片已保存至: ./0105_3/glass0\glass0.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 3 轮合成
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 5
# 第 4 轮合成
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 8
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 6 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 7 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 8 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 9 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 10 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# t-SNE可视化图片已保存至: ./0105_3/glass0\glass0_dss.png
# t-SNE可视化图片已保存至: ./0105_3/glass1\glass1.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 9
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 3 轮合成
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 9
# 第 4 轮合成
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 9
# 第 6 轮合成
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 9
# t-SNE可视化图片已保存至: ./0105_3/glass1\glass1_dss.png
# t-SNE可视化图片已保存至: ./0105_3/haberman\haberman.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 3 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 4 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 6 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 7 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 8 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 9 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 10 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 11 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 12 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 13 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 14 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 15 轮合成
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 5
# t-SNE可视化图片已保存至: ./0105_3/haberman\haberman_dss.png
# t-SNE可视化图片已保存至: ./0105_3/pima\pima.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 7
# 第 3 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 4 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 6 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 7 轮合成
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 5
# 第 8 轮合成
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 5
# 第 9 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 10 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 11 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 12 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 13 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 14 轮合成
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 8
# 第 15 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 16 轮合成
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 8
# 第 17 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 18 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 19 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 20 轮合成
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 21 轮合成
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 7
# 第 22 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 23 轮合成
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 5
# 第 24 轮合成
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 9
# 第 25 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 26 轮合成
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 9
# 第 27 轮合成
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 5
# 第 28 轮合成
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 9
# t-SNE可视化图片已保存至: ./0105_3/pima\pima_dss.png
# t-SNE可视化图片已保存至: ./0105_3/segment0\segment0.png
# 第 1 轮合成
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      23 evol_parameter = EvolutionaryParameterConfig(30, 0.8, 0.2, 100, False)
#      24 dss = DSSMOTE(X=X_train, y=y_train, evol_parameter=evol_parameter)
# ---> 25 X_syn, y_syn = dss.fit_resample_synthesis_only()
#      26 # 可视化, 将DSSMOTE生成的数据与原始数据进行拼接
#      27 y_syn = [2 for _ in range(len(y_syn))]
#
# File D:\Develop\WorkSpace\Python\FCDE\gp_smote_test\ds_smote.py:176, in DSSMOTE.fit_resample_synthesis_only(self)
#     175 def fit_resample_synthesis_only(self):
# --> 176     synthesis_instance = self.synthesis_minority_instance()
#     177     X_resampled_synthes = np.array(synthesis_instance[0])
#     178     y_resampled_synthes = np.array(synthesis_instance[1])
#
# File D:\Develop\WorkSpace\Python\FCDE\gp_smote_test\ds_smote.py:158, in DSSMOTE.synthesis_minority_instance(self)
#     156 while curr_syn < total_syn:
#     157     print('第', index, '轮合成')
# --> 158     syn = self.evolutionary()
#     159     self.min_samples_and_synthesis = np.vstack((self.min_samples_and_synthesis, syn))
#     160     X_syn = X_syn + syn
#
# File D:\Develop\WorkSpace\Python\FCDE\gp_smote_test\ds_smote.py:96, in DSSMOTE.evolutionary(self)
#      94 parent = self.toolbox.selTournament(population, self.parameter.POPSIZE)  # 选择父本
#      95 offspring = varAnd(parent, self.toolbox, self.parameter.CXPB, self.parameter.MUTPB)  # 交叉、变异
# ---> 96 self.toolbox.evaluate(offspring)  # 评估变异后父本
#      98 population = population + offspring
#     100 # 去重
#
# File D:\Develop\WorkSpace\Python\FCDE\gp_smote_test\ds_smote.py:47, in DSSMOTE.evaluate(self, individuals)
#      45 maj_min_dis = maj_dis - min_dis
#      46 # 计算少数类的比例 （第二个目标）
# ---> 47 proportion, _ = minority_class_proportion(self.X_samples, self.y_samples, new_instance,
#      48                                                          len(self.min_samples))
#      49 individual.fitness.values = (maj_min_dis, proportion)
#      51 # 计算与所有少数类（包括新合成的实例）的最小距离
#      52 # （第一个约束：新实例与所有的少数类的最小距离大于DIS，依据DIS的值来控制实例的离散程度）
#
# File D:\Develop\WorkSpace\Python\FCDE\gp_smote_test\data_preprocess.py:106, in minority_class_proportion(x, y, x_new, k)
#      92 """
#      93 计算新实例在k近邻中少数类所占的比例
#      94
#    (...)
#     102 float: 少数类在k近邻中所占的比例
#     103 """
#     105 # 转换为numpy数组以便处理
# --> 106 x = np.array(x)
#     107 y = np.array(y)
#     108 x_new = np.array(x_new)
#
# KeyboardInterrupt:
