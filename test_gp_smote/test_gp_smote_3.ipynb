# %% [markdown]
# ## 测试GP-SMOTE

# %%
from data_preprocess import data_loader, data_preprocess
from visualize import tsne_visualization_binary
from config import EvolutionaryParameterConfig
from gp_smote_test import DSSMOTE
import numpy as np
import warnings

warnings.filterwarnings("ignore")  # 忽略警告

file_path = '../datasets/dat/'
save_path = './0105_3/'
datasetnames = ['iris0', 'ecoli1', 'glass0', 'glass1', 'haberman', 'pima', 'segment0', 'vowel0', 'wisconsin', 'yeast1',
                'shuttle-c0-vs-c4', 'australian', 'heart', 'phoneme', 'ring', 'spambase', 'wdbc']
if __name__ == '__main__':
    print('########\t 开始执行！\t########')
    for datasetname in datasetnames:
        X, y = data_loader(file_path + datasetname + '.dat')
        X_train, X_test, y_train, y_test = data_preprocess(X, y, standard=True, random_state=42)
        # 使用t-SNE进行降维
        X_tsne = tsne_visualization_binary(X_train, y_train, save_path + datasetname, datasetname)  # 传入的是标准化后的特征数据

        # GPSMOTE
        evol_parameter = EvolutionaryParameterConfig(30, 0.8, 0.2, 100, False)
        dss = DSSMOTE(X=X_train, y=y_train, evol_parameter=evol_parameter)
        X_syn, y_syn = dss.fit_resample_synthesis_only()
        # 可视化, 将DSSMOTE生成的数据与原始数据进行拼接
        y_syn = [2 for _ in range(len(y_syn))]
        X_train_resampled = np.vstack((X_train, X_syn))
        y_train_resampled = np.hstack((y_train, y_syn))
        # 4. 使用t-SNE进行降维
        X_tsne_resampled_p_a = tsne_visualization_binary(X_train_resampled, y_train_resampled, save_path + datasetname,
                                                         datasetname + '_dss')
        dss.curve_fitting(save_path + datasetname + '/', 'convergence_curve', datasetname)
        with open(save_path +datasetname + '/'+datasetname +'.txt', 'w') as file:
            file.write(f'实例数量：{X.shape[0]}\n')
            file.write(f'特征数量：{X.shape[1]}\n')
    print('########\t 结束执行！\t########')
# Out:
# ########	 开始执行！	########
# t-SNE可视化图片已保存至: ./0105_3/iris0\iris0.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./0105_3/iris0\iris0_dss.png
# t-SNE可视化图片已保存至: ./0105_3/ecoli1\ecoli1.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 2 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 3 轮合成
# 可行解数量： 17 前沿中个体数： 4 合成实例数： 5
# 第 4 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 6 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 7 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 8 轮合成
# 可行解数量： 3 前沿中个体数： 1 合成实例数： 5
# 第 9 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 10 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 11 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# t-SNE可视化图片已保存至: ./0105_3/ecoli1\ecoli1_dss.png
# t-SNE可视化图片已保存至: ./0105_3/glass0\glass0.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./0105_3/glass0\glass0_dss.png
# t-SNE可视化图片已保存至: ./0105_3/glass1\glass1.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./0105_3/glass1\glass1_dss.png
# t-SNE可视化图片已保存至: ./0105_3/haberman\haberman.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 2 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 3 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 4 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 5 轮合成
# 可行解数量： 5 前沿中个体数： 5 合成实例数： 5
# 第 6 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 7 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 8 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 9 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 10 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./0105_3/haberman\haberman_dss.png
# t-SNE可视化图片已保存至: ./0105_3/pima\pima.png
# 第 1 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 2 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 3 轮合成
# 可行解数量： 1 前沿中个体数： 1 合成实例数： 5
# 第 4 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 5 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 6 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 7 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 8 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 9 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 10 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 11 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 12 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 13 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 14 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 15 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 16 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 17 轮合成
# 可行解数量： 2 前沿中个体数： 2 合成实例数： 5
# 第 18 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./0105_3/pima\pima_dss.png
# t-SNE可视化图片已保存至: ./0105_3/segment0\segment0.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 3 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 4 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 6 轮合成
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 5
# 第 7 轮合成
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 5
# 第 8 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 9 轮合成
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 7
# 第 10 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 11 轮合成
# 可行解数量： 4 前沿中个体数： 1 合成实例数： 5
# 第 12 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 13 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 14 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 15 轮合成
# 可行解数量： 12 前沿中个体数： 4 合成实例数： 5
# 第 16 轮合成
# 可行解数量： 25 前沿中个体数： 4 合成实例数： 5
# 第 17 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 18 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 19 轮合成
# 可行解数量： 25 前沿中个体数： 4 合成实例数： 5
# 第 20 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 21 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 22 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 23 轮合成
# 可行解数量： 20 前沿中个体数： 4 合成实例数： 5
# 第 24 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 25 轮合成
# 可行解数量： 28 前沿中个体数： 5 合成实例数： 5
# 第 26 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 27 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 28 轮合成
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 29 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 30 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 31 轮合成
# 可行解数量： 5 前沿中个体数： 2 合成实例数： 5
# 第 32 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 33 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 34 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 35 轮合成
# 可行解数量： 2 前沿中个体数： 1 合成实例数： 5
# 第 36 轮合成
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 6
# 第 37 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 38 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 39 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 40 轮合成
# 可行解数量： 3 前沿中个体数： 2 合成实例数： 5
# 第 41 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 42 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 43 轮合成
# 可行解数量： 10 前沿中个体数： 5 合成实例数： 5
# 第 44 轮合成
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 5
# 第 45 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 46 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 47 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 48 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 49 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 50 轮合成
# 可行解数量： 24 前沿中个体数： 6 合成实例数： 6
# 第 51 轮合成
# 可行解数量： 4 前沿中个体数： 1 合成实例数： 5
# 第 52 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 53 轮合成
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 7
# 第 54 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 55 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 56 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 57 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 58 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./0105_3/segment0\segment0_dss.png
# t-SNE可视化图片已保存至: ./0105_3/vowel0\vowel0.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 3 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 4 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 6 轮合成
# 可行解数量： 14 前沿中个体数： 9 合成实例数： 9
# 第 7 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 8 轮合成
# 可行解数量： 5 前沿中个体数： 5 合成实例数： 5
# 第 9 轮合成
# 可行解数量： 17 前沿中个体数： 5 合成实例数： 5
# 第 10 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 11 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 12 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 13 轮合成
# 可行解数量： 5 前沿中个体数： 1 合成实例数： 5
# 第 14 轮合成
# 可行解数量： 2 前沿中个体数： 1 合成实例数： 5
# 第 15 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 16 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 17 轮合成
# 可行解数量： 23 前沿中个体数： 14 合成实例数： 14
# 第 18 轮合成
# 可行解数量： 22 前沿中个体数： 11 合成实例数： 11
# 第 19 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 20 轮合成
# 可行解数量： 4 前沿中个体数： 2 合成实例数： 5
# 第 21 轮合成
# 可行解数量： 12 前沿中个体数： 12 合成实例数： 12
# 第 22 轮合成
# 可行解数量： 16 前沿中个体数： 10 合成实例数： 10
# 第 23 轮合成
# 可行解数量： 1 前沿中个体数： 1 合成实例数： 5
# 第 24 轮合成
# 可行解数量： 1 前沿中个体数： 1 合成实例数： 5
# 第 25 轮合成
# 可行解数量： 1 前沿中个体数： 1 合成实例数： 5
# 第 26 轮合成
# 可行解数量： 27 前沿中个体数： 9 合成实例数： 9
# 第 27 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 28 轮合成
# 可行解数量： 8 前沿中个体数： 8 合成实例数： 8
# 第 29 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 30 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 31 轮合成
# 可行解数量： 15 前沿中个体数： 6 合成实例数： 6
# 第 32 轮合成
# 可行解数量： 1 前沿中个体数： 1 合成实例数： 5
# 第 33 轮合成
# 可行解数量： 3 前沿中个体数： 2 合成实例数： 5
# 第 34 轮合成
# 可行解数量： 28 前沿中个体数： 8 合成实例数： 8
# 第 35 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./0105_3/vowel0\vowel0_dss.png
# t-SNE可视化图片已保存至: ./0105_3/wisconsin\wisconsin.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 2 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 3 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 4 轮合成
# 可行解数量： 6 前沿中个体数： 2 合成实例数： 5
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 6 轮合成
# 可行解数量： 1 前沿中个体数： 1 合成实例数： 5
# 第 7 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./0105_3/wisconsin\wisconsin_dss.png
# t-SNE可视化图片已保存至: ./0105_3/yeast1\yeast1.png
# 第 1 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 2 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 3 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 4 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 5 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 6 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 7 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 8 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 9 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 10 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 11 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 12 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 13 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 14 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 15 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 16 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 17 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 18 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 19 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 20 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 21 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 22 轮合成
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 23 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 24 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 25 轮合成
# 可行解数量： 0 前沿中个体数： 0 合成实例数： 5
# 第 26 轮合成
