# %% [markdown]
# ## 测试GP-SMOTE

# %%
from data_preprocess import data_loader, data_preprocess
from visualize import tsne_visualization_binary
from config import EvolutionaryParameterConfig
from gp_smote_test import DSSMOTE
import numpy as np
import warnings

warnings.filterwarnings("ignore")  # 忽略警告

file_path = '../datasets/dat/'
save_path = './1215_2/'
datasetnames = ['iris0', 'ecoli1', 'glass0', 'glass1', 'haberman', 'pima', 'segment0', 'vowel0', 'wisconsin', 'yeast1',
                'shuttle-c0-vs-c4', 'australian', 'heart', 'phoneme', 'ring', 'spambase', 'wdbc']
if __name__ == '__main__':
    print('########\t 开始执行！\t########')
    for datasetname in datasetnames:
        X, y = data_loader(file_path + datasetname + '.dat')
        X_train, X_test, y_train, y_test = data_preprocess(X, y, standard=True, random_state=42)
        # 使用t-SNE进行降维
        X_tsne = tsne_visualization_binary(X_train, y_train, save_path + datasetname, datasetname)  # 传入的是标准化后的特征数据

        # GPSMOTE
        evol_parameter = EvolutionaryParameterConfig(30, 0.8, 0.2, 100, False)
        dss = DSSMOTE(X=X_train, y=y_train, evol_parameter=evol_parameter)
        X_syn, y_syn = dss.fit_resample_synthesis_only()
        # 可视化, 将DSSMOTE生成的数据与原始数据进行拼接
        y_syn = [2 for _ in range(len(y_syn))]
        X_train_resampled = np.vstack((X_train, X_syn))
        y_train_resampled = np.hstack((y_train, y_syn))
        # 4. 使用t-SNE进行降维
        X_tsne_resampled_p_a = tsne_visualization_binary(X_train_resampled, y_train_resampled, save_path + datasetname,
                                                         datasetname + '_dss')
        dss.curve_fitting(save_path + datasetname + '/', 'convergence_curve', datasetname)
        with open(save_path +datasetname + '/'+datasetname +'.txt', 'w') as file:
            file.write(f'实例数量：{X.shape[0]}\n')
            file.write(f'特征数量：{X.shape[1]}\n')
    print('########\t 结束执行！\t########')
# Out:
# ########	 开始执行！	########
# t-SNE可视化图片已保存至: ./1215_2/iris0\iris0.png
# t-SNE可视化图片已保存至: ./1215_2/iris0\iris0_dss.png
# t-SNE可视化图片已保存至: ./1215_2/ecoli1\ecoli1.png
# t-SNE可视化图片已保存至: ./1215_2/ecoli1\ecoli1_dss.png
# t-SNE可视化图片已保存至: ./1215_2/glass0\glass0.png
# t-SNE可视化图片已保存至: ./1215_2/glass0\glass0_dss.png
# t-SNE可视化图片已保存至: ./1215_2/glass1\glass1.png
# t-SNE可视化图片已保存至: ./1215_2/glass1\glass1_dss.png
# t-SNE可视化图片已保存至: ./1215_2/haberman\haberman.png

# %% [markdown]
# ### 测试数据

# %%
from data_preprocess import data_loader, data_preprocess
from sklearn.preprocessing import StandardScaler
from visualize import tsne_visualization_binary
from config import EvolutionaryParameterConfig
from gp_smote import DSSMOTE
import numpy as np
import warnings

warnings.filterwarnings("ignore")  # 忽略警告

file_path = '../datasets/dat/'
save_path = './tsne_results_1209/'
datasetnames = ['iris0', 'ecoli1', 'glass0', 'glass1', 'haberman', 'pima', 'segment0', 'vowel0', 'wisconsin', 'yeast1',
                'shuttle-c0-vs-c4', 'australian', 'heart', 'phoneme', 'ring', 'spambase', 'twonorm', 'wdbc',
                'ionosphere']
if __name__ == '__main__':
    for datasetname in datasetnames:
        X, y = data_loader(file_path + datasetname + '.dat')
        print(f'数据集：{datasetname}')
        print(f'实例数量：{X.shape[0]}')
        print(f'特征数量：{X.shape[1]}')

        X_train, X_test, y_train, y_test = data_preprocess(X, y, standard=True, random_state=42)

        # 使用t-SNE进行降维
        X_tsne = tsne_visualization_binary(X_train, y_train,
                                           save_path=save_path + datasetname,
                                           filename=datasetname, perplexity=30)  # 传入的是标准化后的特征数据
# Out:
# 数据集：iris0
# 实例数量：150
# 特征数量：4
# t-SNE可视化图片已保存至: ./tsne_results_1209/iris0\iris0.png
# 数据集：ecoli1
# 实例数量：336
# 特征数量：7
# t-SNE可视化图片已保存至: ./tsne_results_1209/ecoli1\ecoli1.png
# 数据集：glass0
# 实例数量：214
# 特征数量：9
# t-SNE可视化图片已保存至: ./tsne_results_1209/glass0\glass0.png
# 数据集：glass1
# 实例数量：214
# 特征数量：9
# t-SNE可视化图片已保存至: ./tsne_results_1209/glass1\glass1.png
# 数据集：haberman
# 实例数量：306
# 特征数量：3
# t-SNE可视化图片已保存至: ./tsne_results_1209/haberman\haberman.png
# 数据集：pima
# 实例数量：768
# 特征数量：8
# t-SNE可视化图片已保存至: ./tsne_results_1209/pima\pima.png
# 数据集：segment0
# 实例数量：2308
# 特征数量：19
# t-SNE可视化图片已保存至: ./tsne_results_1209/segment0\segment0.png
# 数据集：vowel0
# 实例数量：988
# 特征数量：13
# t-SNE可视化图片已保存至: ./tsne_results_1209/vowel0\vowel0.png
# 数据集：wisconsin
# 实例数量：683
# 特征数量：9
# t-SNE可视化图片已保存至: ./tsne_results_1209/wisconsin\wisconsin.png
# 数据集：yeast1
# 实例数量：1484
# 特征数量：8
# t-SNE可视化图片已保存至: ./tsne_results_1209/yeast1\yeast1.png
# 数据集：shuttle-c0-vs-c4
# 实例数量：1829
# 特征数量：9
# t-SNE可视化图片已保存至: ./tsne_results_1209/shuttle-c0-vs-c4\shuttle-c0-vs-c4.png
# 数据集：australian
# 实例数量：690
# 特征数量：14
# t-SNE可视化图片已保存至: ./tsne_results_1209/australian\australian.png
# 数据集：heart
# 实例数量：270
# 特征数量：13
# t-SNE可视化图片已保存至: ./tsne_results_1209/heart\heart.png
# 数据集：phoneme
# 实例数量：5404
# 特征数量：5
# t-SNE可视化图片已保存至: ./tsne_results_1209/phoneme\phoneme.png
# 数据集：ring
# 实例数量：7400
# 特征数量：20
# t-SNE可视化图片已保存至: ./tsne_results_1209/ring\ring.png
# 数据集：spambase
# 实例数量：4597
# 特征数量：57
# t-SNE可视化图片已保存至: ./tsne_results_1209/spambase\spambase.png
# 数据集：twonorm
# 实例数量：7400
# 特征数量：20
# t-SNE可视化图片已保存至: ./tsne_results_1209/twonorm\twonorm.png
# 数据集：wdbc
# 实例数量：569
# 特征数量：30
# t-SNE可视化图片已保存至: ./tsne_results_1209/wdbc\wdbc.png
# 数据集：ionosphere
# 实例数量：351
# 特征数量：33
# t-SNE可视化图片已保存至: ./tsne_results_1209/ionosphere\ionosphere.png
