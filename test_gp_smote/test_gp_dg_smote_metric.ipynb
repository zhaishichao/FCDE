# %% [markdown]
# ## 测试GP-SMOTE

# %%
import pandas as pd
import os
from de import DGSMOTE
from data_preprocess import data_loader, data_preprocess
from visualize import tsne_visualization_binary
from config import EvolutionaryParameterConfig
from gp_smote import DSSMOTE
import numpy as np
import warnings

warnings.filterwarnings("ignore")  # 忽略警告

# 保存路径
file_path = '../datasets/dat/'
save_path = './1210/'
save_path_raw = save_path + 'raw/'
save_path_dg = save_path + 'dg/'
save_path_ds = save_path + 'ds/'
# 检查目录是否存在，如果不存在则创建
if not os.path.exists(save_path):
    os.makedirs(save_path)
if not os.path.exists(save_path_raw):
    os.makedirs(save_path_raw)
if not os.path.exists(save_path_dg):
    os.makedirs(save_path_dg)
if not os.path.exists(save_path_dg):
    os.makedirs(save_path_ds)

columns_dataset = ['F-measure', 'G-mean', 'AUC']
columns_datasets = ['数据集', '实例数量', '特征数量', '不平衡比例', 'F-measure', 'G-mean', 'AUC']

# 评价指标
scoring = {
    'f1_macro': 'f1_macro',
    'g_mean': 'g_mean',
    'roc_auc_ovr': 'roc_auc_ovr'
}

datasetnames = ['iris0', 'ecoli1', 'glass0', 'glass1', 'haberman', 'pima', 'segment0', 'vowel0', 'wisconsin', 'yeast1',
                'shuttle-c0-vs-c4', 'australian', 'heart', 'phoneme', 'ring', 'spambase', 'wdbc']
if __name__ == '__main__':

    print('########\t 开始执行！\t########')
    num_run = 10
    for datasetname in datasetnames:
        # 创建带有列名的空DataFrame
        df_dg = pd.DataFrame(columns=columns_datasets)
        df_ds = pd.DataFrame(columns=columns_datasets)
        print('##########\t', '正在处理：', datasetname, '\t##########')
        X, y = data_loader(file_path + datasetname + '.dat')

        X_train, X_test, y_train, y_test = data_preprocess(X, y, standard=True, random_state=42)
        # 使用t-SNE进行降维
        X_tsne = tsne_visualization_binary(X_train, y_train, save_path + datasetname, datasetname)  # 传入的是标准化后的特征数据

        evol_parameter = EvolutionaryParameterConfig(30, 0.8, 0.2, 100, False)

        # DGSMOTE
        dg = DGSMOTE(X=X_train, y=y_train, evol_parameter=evol_parameter)
        X_syn, y_syn = dg.fit_resample_synthesis_only()
        # 可视化, 将DSSMOTE生成的数据与原始数据进行拼接
        y_syn = [2 for _ in range(len(y_syn))]
        X_train_resampled = np.vstack((X_train, X_syn))
        y_train_resampled = np.hstack((y_train, y_syn))
        # 4. 使用t-SNE进行降维
        X_tsne_resampled_dg = tsne_visualization_binary(X_train_resampled, y_train_resampled, save_path + datasetname,
                                                        datasetname + '_dg')

        # GPSMOTE
        dss = DSSMOTE(X=X_train, y=y_train, evol_parameter=evol_parameter)
        X_syn, y_syn = dss.fit_resample_synthesis_only()
        # 可视化, 将DSSMOTE生成的数据与原始数据进行拼接
        y_syn = [2 for _ in range(len(y_syn))]
        X_train_resampled = np.vstack((X_train, X_syn))
        y_train_resampled = np.hstack((y_train, y_syn))
        # 使用t-SNE进行降维
        X_tsne_resampled_ds = tsne_visualization_binary(X_train_resampled, y_train_resampled, save_path + datasetname,
                                                        datasetname + '_ds')

    print('########\t 结束执行！\t########')
# Out:
# ########	 开始执行！	########
# t-SNE可视化图片已保存至: ./1210/iris0\iris0.png
# t-SNE可视化图片已保存至: ./1210/iris0\iris0_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/iris0\iris0_ds.png
# t-SNE可视化图片已保存至: ./1210/ecoli1\ecoli1.png
# t-SNE可视化图片已保存至: ./1210/ecoli1\ecoli1_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 11 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 12 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 13 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/ecoli1\ecoli1_ds.png
# t-SNE可视化图片已保存至: ./1210/glass0\glass0.png
# t-SNE可视化图片已保存至: ./1210/glass0\glass0_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/glass0\glass0_ds.png
# t-SNE可视化图片已保存至: ./1210/glass1\glass1.png
# t-SNE可视化图片已保存至: ./1210/glass1\glass1_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/glass1\glass1_ds.png
# t-SNE可视化图片已保存至: ./1210/haberman\haberman.png
# t-SNE可视化图片已保存至: ./1210/haberman\haberman_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/haberman\haberman_ds.png
# t-SNE可视化图片已保存至: ./1210/pima\pima.png
# t-SNE可视化图片已保存至: ./1210/pima\pima_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 17 合成实例数： 17
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 11 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 12 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 13 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 14 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 15 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 16 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/pima\pima_ds.png
# t-SNE可视化图片已保存至: ./1210/segment0\segment0.png
# t-SNE可视化图片已保存至: ./1210/segment0\segment0_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 22 合成实例数： 22
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 11 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 12 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 13 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 14 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 15 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 16 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 17 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 18 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 19 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 20 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 21 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 22 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 23 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 24 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 25 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 26 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 27 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 28 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 29 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 30 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 31 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 15 合成实例数： 15
# 第 32 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 33 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 34 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 35 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 36 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 15 合成实例数： 15
# 第 37 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 38 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 39 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 40 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 41 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 42 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 43 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 44 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 45 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 46 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 47 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 48 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 49 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 50 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 51 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 52 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 53 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 54 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 55 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 56 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 57 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 58 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 59 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 60 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 61 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 62 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 63 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 64 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 65 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 66 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 67 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 68 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 17 合成实例数： 17
# 第 69 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 70 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 71 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 72 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 73 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 74 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 75 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 76 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 77 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 28 合成实例数： 28
# 第 78 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 79 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 80 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 81 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 82 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 83 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 84 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 85 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 86 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 87 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 88 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 89 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 90 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 91 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 92 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 93 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 94 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 17 合成实例数： 17
# 第 95 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 96 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 97 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 98 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 21 合成实例数： 21
# 第 99 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 100 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 101 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 102 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 103 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 104 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 105 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/segment0\segment0_ds.png
# t-SNE可视化图片已保存至: ./1210/vowel0\vowel0.png
# t-SNE可视化图片已保存至: ./1210/vowel0\vowel0_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 11 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 12 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 13 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 14 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 15 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 16 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 17 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 18 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 19 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 20 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 21 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 22 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 23 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 24 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 25 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 26 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 27 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 24 合成实例数： 24
# 第 28 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 29 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 30 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 31 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 32 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 33 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 34 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 35 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 36 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 37 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 38 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 39 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 40 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 41 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 42 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 43 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 44 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 45 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 46 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 47 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 48 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 49 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/vowel0\vowel0_ds.png
# t-SNE可视化图片已保存至: ./1210/wisconsin\wisconsin.png
# t-SNE可视化图片已保存至: ./1210/wisconsin\wisconsin_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 11 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 12 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 13 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 14 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 15 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/wisconsin\wisconsin_ds.png
# t-SNE可视化图片已保存至: ./1210/yeast1\yeast1.png
# t-SNE可视化图片已保存至: ./1210/yeast1\yeast1_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 11 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 12 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 13 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 14 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 15 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 16 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 17 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 18 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 19 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 20 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 21 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 22 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 23 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 24 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 25 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 26 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 27 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 28 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 29 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 30 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 31 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 32 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 33 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 34 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 35 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 36 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 37 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 38 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 39 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 40 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 41 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 42 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 43 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 44 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/yeast1\yeast1_ds.png
# t-SNE可视化图片已保存至: ./1210/shuttle-c0-vs-c4\shuttle-c0-vs-c4.png
# t-SNE可视化图片已保存至: ./1210/shuttle-c0-vs-c4\shuttle-c0-vs-c4_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 11 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 12 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 13 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 14 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 15 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 16 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 17 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 18 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 19 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 20 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 21 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 22 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 23 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 24 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 25 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 26 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 27 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 28 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 29 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 30 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 31 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 32 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 33 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 34 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 35 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 36 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 37 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 38 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 39 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 40 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 41 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 42 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 43 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 44 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 45 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 46 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 47 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 48 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 49 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 50 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 51 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 52 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 53 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 54 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 55 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 56 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 57 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 58 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 59 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 60 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 61 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 62 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 63 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 64 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 65 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 66 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 67 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 68 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 69 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 70 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 71 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 72 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 73 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 74 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 75 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 76 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 77 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 78 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 79 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 80 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 81 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 82 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 83 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 84 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 85 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 86 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 87 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 88 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 89 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 90 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 91 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 92 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 93 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 94 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 95 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 96 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 97 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 98 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 99 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 100 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 101 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 102 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 103 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 104 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 105 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 106 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 107 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 108 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 109 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 110 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 1 合成实例数： 10
# 第 111 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/shuttle-c0-vs-c4\shuttle-c0-vs-c4_ds.png
# t-SNE可视化图片已保存至: ./1210/australian\australian.png
# t-SNE可视化图片已保存至: ./1210/australian\australian_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/australian\australian_ds.png
# t-SNE可视化图片已保存至: ./1210/heart\heart.png
# t-SNE可视化图片已保存至: ./1210/heart\heart_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 2 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./1210/heart\heart_ds.png
# t-SNE可视化图片已保存至: ./1210/phoneme\phoneme.png
# t-SNE可视化图片已保存至: ./1210/phoneme\phoneme_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 11 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 12 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 13 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 14 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 15 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 16 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 17 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 18 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 19 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 20 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 21 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 22 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 23 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 24 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 25 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 26 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 27 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 28 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 29 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 30 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 31 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 32 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 33 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 20 合成实例数： 20
# 第 34 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 35 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 36 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 37 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 38 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 39 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 40 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 41 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 42 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 43 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 44 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 45 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 46 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 47 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 48 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 49 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 50 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 51 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 52 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 53 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 54 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 55 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 56 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 57 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 58 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 59 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 60 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 61 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 62 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 63 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 64 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 65 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 66 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 67 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 68 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 69 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 70 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 71 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 72 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 73 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 74 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 75 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 76 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 17 合成实例数： 17
# 第 77 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 78 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# 第 79 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 80 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 81 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 82 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 83 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 84 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 85 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 86 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 87 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 88 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 22 合成实例数： 22
# 第 89 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 90 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 91 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 92 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 93 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 94 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 95 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 96 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 97 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 98 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 22 合成实例数： 22
# 第 99 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 100 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 101 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 102 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 103 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 104 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 105 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 106 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 18 合成实例数： 18
# 第 107 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 108 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 109 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 110 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 111 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 112 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 113 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 114 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 115 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 19 合成实例数： 19
# 第 116 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 117 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 118 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 119 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 120 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 121 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 122 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 18 合成实例数： 18
# 第 123 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 124 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 125 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 126 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 127 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 128 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 129 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 130 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 131 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 132 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 133 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 134 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 135 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 136 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 137 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 138 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 18 合成实例数： 18
# 第 139 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 140 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 141 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 142 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# t-SNE可视化图片已保存至: ./1210/phoneme\phoneme_ds.png
# t-SNE可视化图片已保存至: ./1210/ring\ring.png
# t-SNE可视化图片已保存至: ./1210/ring\ring_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 18 合成实例数： 18
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# t-SNE可视化图片已保存至: ./1210/ring\ring_ds.png
# t-SNE可视化图片已保存至: ./1210/spambase\spambase.png
# t-SNE可视化图片已保存至: ./1210/spambase\spambase_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 17 合成实例数： 17
# 第 11 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 12 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 13 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 16 合成实例数： 16
# 第 14 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 15 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 16 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 17 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 16 合成实例数： 16
# 第 18 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 19 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 15 合成实例数： 15
# 第 20 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 21 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 15 合成实例数： 15
# 第 22 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 23 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 24 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 25 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 26 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 27 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 28 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 29 合成实例数： 29
# 第 29 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 30 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 18 合成实例数： 18
# 第 31 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 18 合成实例数： 18
# 第 32 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 16 合成实例数： 16
# 第 33 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 34 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 35 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 36 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 13 合成实例数： 13
# 第 37 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 38 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 39 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 40 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 41 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 42 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 43 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 14 合成实例数： 14
# 第 44 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 15 合成实例数： 15
# 第 45 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 46 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# 第 47 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 48 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 11 合成实例数： 11
# 第 49 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 50 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 10 合成实例数： 10
# 第 51 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 12 合成实例数： 12
# 第 52 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 53 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./1210/spambase\spambase_ds.png
# t-SNE可视化图片已保存至: ./1210/wdbc\wdbc.png
# t-SNE可视化图片已保存至: ./1210/wdbc\wdbc_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 3 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 9 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 8 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 9 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 4 合成实例数： 10
# 第 10 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 30 合成实例数： 30
# t-SNE可视化图片已保存至: ./1210/wdbc\wdbc_ds.png
# t-SNE可视化图片已保存至: ./1210/ionosphere\ionosphere.png
# t-SNE可视化图片已保存至: ./1210/ionosphere\ionosphere_dg.png
# 第 1 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 2 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 3 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 4 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 6 合成实例数： 10
# 第 5 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 5 合成实例数： 10
# 第 6 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 7 合成实例数： 10
# 第 7 轮合成
# ########### 	 Start the evolution! 	 ##########
# 可行解数量： 30 前沿中个体数： 8 合成实例数： 10
# t-SNE可视化图片已保存至: ./1210/ionosphere\ionosphere_ds.png
# ########	 结束执行！	########
